# %% [markdown]
# # NLP Project 2
#
# **ESILV A4 DIA6 — 2026**
#
#
#
# **Authors:** Leo WINTER & Alvaro SERERO

# %% [markdown]
# ## Table of Contents
# 1. [Setup & Imports](#setup)
# 2. [Load Data](#load)
# 3. [Baseline ML model](#model1)
# 4. [Model with embeddings](#model_keras)
#     - 4.1 [Model with trained embeddings](#model2)
#     - 4.2 [Model with pre-trained embeddings](#model3)
# 6. [USE](#model4)
# 7. [LLM](#model5)
# 8. [Comparaison](#comparaison)

# %% [markdown]
# <a id="setup"></a>
# ## 1. Setup & Imports

# %%
from pathlib import Path
import os, pickle, ast, datetime

import pandas as pd
import numpy as np
from tqdm.auto import tqdm

import gensim.downloader
from gensim.models import Word2Vec
from gensim.models.callbacks import CallbackAny2Vec

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.decomposition import PCA

import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Embedding, GlobalMaxPooling1D,SpatialDropout1D,
                                      Dense, Dropout,Conv1D,BatchNormalization,
                                      LSTM, Bidirectional)
from tensorflow.keras.callbacks import EarlyStopping

from transformers import pipeline


import matplotlib.pyplot as plt
import seaborn as sns



# Setting up the Paths
CURRENT_DIR = Path.cwd()
DATA_PATH = CURRENT_DIR.parent / "data"
MODEL_PATH = CURRENT_DIR.parent / "model"
VISU_PATH = CURRENT_DIR.parent / "visualizations" / "notebook3"
LOG_DIR = CURRENT_DIR.parent / "logs" / "projector"
VISU_PATH.mkdir(parents=True, exist_ok=True)
LOG_DIR.mkdir(parents=True, exist_ok=True)

# %%
class TqdmCallback(CallbackAny2Vec):
    def __init__(self, total):
        self.pbar  = tqdm(total=total, desc="Word2Vec epochs")
        self.epoch = 0
    def on_epoch_end(self, model):
        self.epoch += 1
        self.pbar.update(1)
        if self.epoch == self.pbar.total:
            self.pbar.close()


class Word2VecModel:
    """
    Wrapper around gensim Word2Vec providing a clean interface for:
    similarity, distance, analogy, 2D visualisation, sentence vectors,
    and semantic search — matching the GloVe interface below.
    """
    def __init__(self, vector_size=100, window=5, min_count=2, sg=1, epochs=10):
        self.vector_size = vector_size
        self.window, self.min_count = window, min_count
        self.sg, self.epochs = sg, epochs
        self.model = None

    def train(self, sentences):
        cb = TqdmCallback(self.epochs)
        self.model = Word2Vec(
            sentences=sentences, vector_size=self.vector_size,
            window=self.window, min_count=self.min_count,
            workers=4, epochs=self.epochs, sg=self.sg, callbacks=[cb]
        )

    def save(self, name):
        if self.model:
            self.model.save(str(MODEL_PATH / f"{name}.model"))
            print(f"Saved → {name}.model")

    def load(self, name):
        path = MODEL_PATH / f"{name}.model"
        if path.exists():
            self.model = Word2Vec.load(str(path))
            print(f"Loaded ← {name}.model")
        else:
            print(f"Not found: {path}")

    # ── Vocab helpers ─────────────────────────────────────────────────────────
    def __contains__(self, w):   return self.model and w in self.model.wv
    def vec(self, w):            return self.model.wv[w]
    def vocab(self):             return self.model.wv.index_to_key
    def vocab_size(self):        return len(self.model.wv.index_to_key)
    def n_dims(self):            return self.vector_size

    # ── Distances (section 5) ─────────────────────────────────────────────────
    def cosine(self, w1, w2):
        """Cosine similarity between two words (range: −1 to 1, higher = more similar)."""
        if w1 in self and w2 in self:
            v1, v2 = self.vec(w1), self.vec(w2)
            return float(np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)))
        return None

    def euclidean(self, w1, w2):
        """Euclidean distance between two word vectors (lower = more similar)."""
        if w1 in self and w2 in self:
            return float(np.linalg.norm(self.vec(w1) - self.vec(w2)))
        return None

    # ── Analogy (section 6) ───────────────────────────────────────────────────
    def analogy(self, positive, negative, topn=5):
        """
        Word analogy: find words such that
        positive[0] - negative[0] + positive[1] ≈ result
        Classic example: king - man + woman ≈ queen
        """
        return self.model.wv.most_similar(positive=positive, negative=negative, topn=topn)

    def most_similar(self, word, topn=10):
        return self.model.wv.most_similar(word, topn=topn)

    # ── Visualisation ─────────────────────────────────────────────────────────
    def plot_2d(self, words, title="Word2Vec 2D", fname=None):
        valid  = [w for w in words if w in self]
        if len(valid) < 2: print("Not enough words."); return
        vecs   = np.array([self.vec(w) for w in valid])
        coords = PCA(n_components=2).fit_transform(vecs)
        plt.figure(figsize=(10, 7))
        plt.scatter(coords[:, 0], coords[:, 1], color="#1565C0",
                    edgecolors="white", s=60, zorder=3)
        for i, w in enumerate(valid):
            plt.annotate(w, (coords[i, 0], coords[i, 1]),
                         xytext=(5, 3), textcoords="offset points", fontsize=8)
        plt.title(title, fontweight="bold")
        plt.grid(True, linestyle="--", alpha=0.3); plt.tight_layout()
        if fname: plt.savefig(VISU_PATH / f"{fname}.png", bbox_inches="tight")
        plt.show()

    # ── Sentence vectors (section 8) ──────────────────────────────────────────
    def sentence_vec(self, tokens, idf=None):
        """
        TF-IDF weighted mean of word vectors.
        Rare, informative words get higher weight than frequent generic words.
        Returns None if no known words are found.
        """
        valid = [(self.vec(w), idf.get(w, 1.0) if idf else 1.0)
                 for w in tokens if w in self]
        if not valid: return None
        vecs, ws = zip(*valid)
        return np.average(vecs, axis=0, weights=ws)

    def semantic_search(self, query_tokens, corpus_vecs, corpus_idx, top_n=3, idf=None):
        qv = self.sentence_vec(query_tokens, idf)
        if qv is None: return []
        mat   = np.array(corpus_vecs)
        norms = np.linalg.norm(mat, axis=1) * np.linalg.norm(qv)
        sims  = np.divide(np.dot(mat, qv), norms,
                          out=np.zeros(len(mat)), where=norms != 0)
        top_pos = list(np.argsort(sims)[-top_n:][::-1])
        return [corpus_idx[p] for p in top_pos]

class GloVeModel:
    """
    Wrapper around a pre-trained gensim KeyedVectors object.
    Provides the same interface as Word2VecModel so both can be used
    interchangeably in comparison and search code.
    """
    def __init__(self, name: str):
        cache = MODEL_PATH / f"{name}.vecs"
        if cache.exists():
            print(f"Loading {name} from cache…")
            with open(cache, "rb") as f:
                self.kv = pickle.load(f)
        else:
            print(f"Downloading {name} (first run only, ~130 MB)…")
            self.kv = gensim.downloader.load(name)
            with open(cache, "wb") as f:
                pickle.dump(self.kv, f)
        print(f"Loaded: {len(self.kv.index_to_key):,} words, {self.kv.vector_size} dimensions")

    def __contains__(self, w):   return w in self.kv
    def vec(self, w):            return np.array(self.kv[w])
    def vocab(self):             return self.kv.index_to_key
    def vocab_size(self):        return len(self.kv.index_to_key)
    def n_dims(self):            return self.kv.vector_size
    def most_similar(self, w, topn=10): return self.kv.most_similar(w, topn=topn)

    def cosine(self, w1, w2):
        if w1 in self and w2 in self:
            v1, v2 = self.vec(w1), self.vec(w2)
            return float(np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)))
        return None

    def euclidean(self, w1, w2):
        if w1 in self and w2 in self:
            return float(np.linalg.norm(self.vec(w1) - self.vec(w2)))
        return None

    def analogy(self, positive, negative, topn=5):
        return self.kv.most_similar(positive=positive, negative=negative, topn=topn)

    def sentence_vec(self, tokens, idf=None):
        valid = [(self.vec(w), idf.get(w, 1.0) if idf else 1.0)
                 for w in tokens if w in self]
        if not valid:
            return np.zeros(self.n_dims())
        vecs, ws = zip(*valid)
        return np.average(vecs, axis=0, weights=ws)

    def semantic_search(self, query_tokens, corpus_vecs, corpus_idx, top_n=3, idf=None):
        qv = self.sentence_vec(query_tokens, idf)
        if np.all(qv == 0): return []
        mat   = np.array(corpus_vecs)
        norms = np.linalg.norm(mat, axis=1) * np.linalg.norm(qv)
        sims  = np.divide(np.dot(mat, qv), norms,
                          out=np.zeros(len(mat)), where=norms != 0)
        top_pos = list(np.argsort(sims)[-top_n:][::-1])
        return [corpus_idx[p] for p in top_pos]

    def plot_2d(self, words, title="GloVe 2D", fname=None):
        valid  = [w for w in words if w in self]
        if len(valid) < 2: return
        vecs   = np.array([self.vec(w) for w in valid])
        coords = PCA(n_components=2).fit_transform(vecs)
        plt.figure(figsize=(10, 7))
        plt.scatter(coords[:, 0], coords[:, 1], color="#0D47A1",
                    edgecolors="white", s=60, zorder=3)
        for i, w in enumerate(valid):
            plt.annotate(w, (coords[i, 0], coords[i, 1]),
                         xytext=(5, 3), textcoords="offset points", fontsize=8)
        plt.title(title, fontweight="bold")
        plt.grid(True, linestyle="--", alpha=0.3); plt.tight_layout()
        if fname: plt.savefig(VISU_PATH / f"{fname}.png", bbox_inches="tight")
        plt.show()


model_glove = GloVeModel("glove-wiki-gigaword-100")
# Out:
# Loading glove-wiki-gigaword-100 from cache…
# Loaded: 400,000 words, 100d

# %% [markdown]
# <a id="load"></a>
# ## 2. Load Data

# %%
# Load data saved in the second notebook
def load_data():
    path_parquet = DATA_PATH / "reviews_modeled.parquet"
    path_csv = DATA_PATH / "reviews_modeled.csv"

    if path_parquet.exists():
        try:
            df = pd.read_parquet(path_parquet)
            return df
        except Exception as e:
            print(e)

    if path_csv.exists():
        try:
            df = pd.read_csv(path_csv)
            return df
        except Exception as e:
            print(e)
    return None


dataset = load_data()
if dataset is None: 
    dataset = pd.DataFrame() #To not have None warnings
display(dataset.head(2))
data_model = dataset.copy()
# Out:
#    note            auteur                                               avis  \
# 0     5  brahim--k-131532  Meilleurs assurances, prix, solutions, écoute,...
# 1     4  bernard-g-112497  je suis globalement satisfait , sauf que vous ...
#
#            assureur produit   type date_publication    date_exp  \
# 0  Direct Assurance    auto  train       2021-09-06  2021-09-01
# 1  Direct Assurance    auto  train       2021-05-03  2021-05-01
#
#                                              avis_en  \
# 0  Best insurance, price, solutions, listening, s...
# 1  I am generally satisfied, except that you have...
#
#                                             avis_cor  \
# 0  meilleurs assurances prix solutions écoute rap...
# 1  je suis globalement satisfait sauf que vous av...
#
#                                          avis_cor_en year_month  \
# 0  best insurance price solutions listening speed...    2021-09
# 1  i am generally satisfied except that you have ...    2021-05
#
#                                            tokens_en  \
# 0  ['good', 'price', 'solution', 'listen', 'speed...
# 1  ['generally', 'satisfied', 'except', 'problem'...
#
#                                               tokens  cluster_en  cluster_fr
# 0  ['meilleur', 'prix', 'solution', 'écoute', 'ra...           1           1
# 1  ['globalement', 'satisfait', 'sauf', 'problème...           0           2

# %%
def label_sentiment(rating):
    if rating <= 2: return 0 
    if rating == 3: return 1 
    return 2                 

data_model['emotion'] = data_model['note'].apply(label_sentiment)
X_en = data_model['tokens_en']
X_fr = data_model['tokens']
y = data_model['note']
y = y - 1 # To have labels from 0 to 4 and not from 1 to 5

X_train_en, X_test_en, y_train_en, y_test_en = train_test_split(X_en, y, test_size=0.2, random_state=42, stratify=y)
X_train_fr, X_test_fr, y_train_fr, y_test_fr = train_test_split(X_fr, y, test_size=0.2, random_state=42, stratify=y)

X_train_list_en = [ast.literal_eval(x) for x in X_train_en.tolist()]
X_test_list_en = [ast.literal_eval(x) for x in X_test_en.tolist()]

X_train_list_fr = [ast.literal_eval(x) for x in X_train_fr.tolist()]
X_test_list_fr = [ast.literal_eval(x) for x in  X_test_fr.tolist()]

# %%
model_w2v_en = Word2VecModel(vector_size=100, window=5, min_count=2, sg=1, epochs=10)
model_w2v_fr = Word2VecModel(vector_size=100, window=5, min_count=2, sg=1, epochs=10)
model_glove = GloVeModel("glove-wiki-gigaword-100")

if (MODEL_PATH / "word2vec_en.model").exists():
    model_w2v_en.load("word2vec_en")
else:
    print("W2v English model not found")
if (MODEL_PATH / "word2vec_fr.model").exists():
    model_w2v_fr.load("word2vec_fr")
else:
    print("W2v French model not found")
# Out:
# Loading glove-wiki-gigaword-100 from cache…
# Loaded: 400,000 words, 100d
# Loaded ← word2vec_en.model
# Loaded ← word2vec_fr.model

# %% [markdown]
# <a id="model1"></a>
# ## 3. Baseline ML model

# %%
def model1(X_train, X_test, y_train, y_test):
    tfidf = TfidfVectorizer(ngram_range=(1,2), sublinear_tf=True, max_features=20_000)
    X_train_tfidf = tfidf.fit_transform(X_train)
    X_test_tfidf = tfidf.transform(X_test)

    model_lr = LogisticRegression(max_iter=1000, class_weight='balanced')
    model_lr.fit(X_train_tfidf, y_train)

    y_pred = model_lr.predict(X_test_tfidf)
    accuracy = accuracy_score(y_test, y_pred)
    print(classification_report(y_test, y_pred))
    
    return tfidf,model_lr,accuracy

# %%
print("English model note:")
tfidf_en, model_lr_en,accuracy1_en = model1(X_train_en, X_test_en, y_train_en, y_test_en)
print("\nFrench model note:")
tfidf_fr, model_lr_fr,accuracy1_fr = model1(X_train_fr, X_test_fr, y_train_fr, y_test_fr)
# Out:
# English model note:
#               precision    recall  f1-score   support
#
#            0       0.67      0.66      0.66      1453
#            1       0.35      0.38      0.36       743
#            2       0.28      0.29      0.28       677
#            3       0.42      0.38      0.40       977
#            4       0.54      0.55      0.54       969
#
#     accuracy                           0.49      4819
#    macro avg       0.45      0.45      0.45      4819
# weighted avg       0.49      0.49      0.49      4819
#
#
# French model note:
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67      1453
#            1       0.36      0.40      0.38       743
#            2       0.31      0.29      0.30       677
#            3       0.46      0.42      0.44       977
#            4       0.56      0.58      0.57       969
#
#     accuracy                           0.50      4819
#    macro avg       0.47      0.47      0.47      4819
# weighted avg       0.51      0.50      0.50      4819

# %%
def plot_top_coefficients(vectorizer, model, n_words=10):
    feature_names = vectorizer.get_feature_names_out()
    coefs = model.coef_[0]
    
    top_pos = np.argsort(coefs)[-n_words:]
    top_neg = np.argsort(coefs)[:n_words]
    
    print("Important negative worlds:", [feature_names[i] for i in top_neg])
    print("Important positive worlds:", [feature_names[i] for i in top_pos])

print("English note:")
print(f"accuracy = {accuracy1_en:.2f}")
plot_top_coefficients(tfidf_en, model_lr_en)
print("\nFrench note:")
print(f"accuracy = {accuracy1_fr:.2f}")
plot_top_coefficients(tfidf_fr, model_lr_fr)
# Out:
# English note:
# accuracy = 0.49
# Important negative worlds: ['satisfied', 'thank', 'good', 'price', 'fast', 'moment', 'quick', 'easy', 'hope', 'satisfied service']
# Important positive worlds: ['expensive', 'impossible', 'reimburse', 'pay', 'terminate', 'month', 'incompetent', 'increase', 'avoid', 'flee']
#
# French note:
# accuracy = 0.50
# Important negative worlds: ['satisfait', 'satisfaite', 'rapide', 'merci', 'prix', 'très', 'espère', 'écoute', 'bon', 'efficace']
# Important positive worlds: ['argent', 'incompétent', 'nul', 'aucun', 'déconseille', 'aucune', 'éviter', 'fuyez', 'mois', 'fuir']

# %% [markdown]
# <a id="model_keras"></a>
# ## 4. Model with embeddings keras

# %%
max_words = 10000  
max_length = 100
vector_size=100

tokenizer_en = Tokenizer(num_words=max_words, oov_token="<OOV>",filters='',lower=False)
tokenizer_en.fit_on_texts(X_train_list_en)

X_train_seq_en = tokenizer_en.texts_to_sequences(X_train_list_en)
X_test_seq_en = tokenizer_en.texts_to_sequences(X_test_list_en)
X_train_pad_en = pad_sequences(X_train_seq_en, maxlen=max_length, padding='post')
X_test_pad_en = pad_sequences(X_test_seq_en, maxlen=max_length, padding='post')


tokenizer_fr = Tokenizer(num_words=max_words, oov_token="<OOV>", filters='',lower=False)
tokenizer_fr.fit_on_texts(X_train_list_fr)

X_train_seq_fr = tokenizer_fr.texts_to_sequences(X_train_list_fr)
X_test_seq_fr = tokenizer_fr.texts_to_sequences(X_test_list_fr)
X_train_pad_fr = pad_sequences(X_train_seq_fr, maxlen=max_length, padding='post')
X_test_pad_fr = pad_sequences(X_test_seq_fr, maxlen=max_length, padding='post')

def get_embedding_matrix(tokenizer, word2vec_model, embedding_dim):
    vocab_size = len(tokenizer.word_index) + 1
    embedding_matrix = np.zeros((vocab_size, embedding_dim))
    
    for word, i in tokenizer.word_index.items():
        if word in word2vec_model:
            embedding_matrix[i] = word2vec_model.vec(word)
            
    return embedding_matrix

# %% [markdown]
# <a id="model2"></a>
# ### 4.1 Model with trained embeddings

# %%
def model2_en(embedding_matrix,embedding_dim = 100):
    vocab_size, embedding_dim = embedding_matrix.shape
   
    model = Sequential([
        Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix],
                  trainable=False),
                  
        SpatialDropout1D(0.5),
        Conv1D(128, 5, activation='relu', padding='same'),
        GlobalMaxPooling1D(),
        BatchNormalization(), 
        
        Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.0001)),

        Dropout(0.5),
        Dense(5, activation='softmax')
    ])
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(loss='sparse_categorical_crossentropy', 
                      optimizer=optimizer, 
                      metrics=['accuracy'])
    return model

def model2_fr(embedding_matrix,embedding_dim = 100):
    vocab_size, embedding_dim = embedding_matrix.shape
   
    model = Sequential([
        Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix],
                  trainable=False),
                  
        SpatialDropout1D(0.2),
        Conv1D(128, 5, activation='relu', padding='same'),
        GlobalMaxPooling1D(),
        BatchNormalization(), 
        
        Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.0001)),

        Dropout(0.5),
        Dense(5, activation='softmax')
    ])
    model.compile(loss='sparse_categorical_crossentropy', 
                      optimizer='adam', 
                      metrics=['accuracy'])
    return model

# %%
embedding_matrix_en = get_embedding_matrix(tokenizer_en, model_w2v_en, vector_size)
embedding_matrix_fr = get_embedding_matrix(tokenizer_fr, model_w2v_fr, vector_size)

model_embeddings_en = model2_en(embedding_matrix_en)
model_embeddings_en.build(input_shape=(None, max_length))
model_embeddings_en.summary()

model_embeddings_fr = model2_fr(embedding_matrix_fr)
# Out:
# Model: "sequential_41"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_41 (Embedding)        │ (None, 100, 100)       │     1,135,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout1d_12            │ (None, 100, 100)       │             0 │
# │ (SpatialDropout1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_45 (Conv1D)              │ (None, 100, 128)       │        64,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d_43         │ (None, 128)            │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_82 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_41 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_83 (Dense)                │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,208,621 (4.61 MB)
#  Trainable params: 72,965 (285.02 KB)
#  Non-trainable params: 1,135,656 (4.33 MB)

# %%
log_dir = str(LOG_DIR / "fit" / f"{datetime.datetime.now().strftime("%Y%m%d-%H%M%S")}")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
early_stop = EarlyStopping(
    monitor='val_loss', 
    patience=10,          
    restore_best_weights=True 
)

print("English model :")
history = model_embeddings_en.fit(
    X_train_pad_en, y_train_en,
    epochs=100,
    validation_data=(X_test_pad_en, y_test_en),
    callbacks=[tensorboard_callback,early_stop],
    batch_size=32
)


print("\nFrench model :")
history = model_embeddings_fr.fit(
    X_train_pad_fr, y_train_fr,
    epochs=100,
    validation_data=(X_test_pad_fr, y_test_fr),
    callbacks=[tensorboard_callback,early_stop],
    batch_size=32
)
# Out:
# English model :
# Epoch 1/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.3136 - loss: 1.8516 - val_accuracy: 0.4397 - val_loss: 1.3139
# Epoch 2/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.3797 - loss: 1.5171 - val_accuracy: 0.4565 - val_loss: 1.2618
# Epoch 3/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4009 - loss: 1.4314 - val_accuracy: 0.4630 - val_loss: 1.2316
# Epoch 4/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4187 - loss: 1.3695 - val_accuracy: 0.4804 - val_loss: 1.2066
# Epoch 5/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.4207 - loss: 1.3274 - val_accuracy: 0.4864 - val_loss: 1.1949
# Epoch 6/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 25s 25ms/step - accuracy: 0.4337 - loss: 1.2947 - val_accuracy: 0.4866 - val_loss: 1.1895
# Epoch 7/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 14s 24ms/step - accuracy: 0.4463 - loss: 1.2705 - val_accuracy: 0.4868 - val_loss: 1.1796
# Epoch 8/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 22s 27ms/step - accuracy: 0.4505 - loss: 1.2524 - val_accuracy: 0.4922 - val_loss: 1.1745
# Epoch 9/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.4627 - loss: 1.2319 - val_accuracy: 0.4895 - val_loss: 1.1689
# Epoch 10/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4669 - loss: 1.2226 - val_accuracy: 0.4947 - val_loss: 1.1618
# Epoch 11/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4702 - loss: 1.2097 - val_accuracy: 0.4962 - val_loss: 1.1601
# Epoch 12/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4791 - loss: 1.1978 - val_accuracy: 0.4953 - val_loss: 1.1537
# Epoch 13/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4744 - loss: 1.1997 - val_accuracy: 0.4972 - val_loss: 1.1509
# Epoch 14/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4834 - loss: 1.1868 - val_accuracy: 0.4991 - val_loss: 1.1569
# Epoch 15/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.4789 - loss: 1.1884 - val_accuracy: 0.5018 - val_loss: 1.1492
# Epoch 16/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.4844 - loss: 1.1795 - val_accuracy: 0.5007 - val_loss: 1.1413
# Epoch 17/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4870 - loss: 1.1750 - val_accuracy: 0.5005 - val_loss: 1.1489
# Epoch 18/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4843 - loss: 1.1689 - val_accuracy: 0.5022 - val_loss: 1.1420
# Epoch 19/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4889 - loss: 1.1644 - val_accuracy: 0.4997 - val_loss: 1.1441
# Epoch 20/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4917 - loss: 1.1581 - val_accuracy: 0.5016 - val_loss: 1.1338
# Epoch 21/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4923 - loss: 1.1555 - val_accuracy: 0.5038 - val_loss: 1.1272
# Epoch 22/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.4914 - loss: 1.1526 - val_accuracy: 0.5032 - val_loss: 1.1317
# Epoch 23/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4945 - loss: 1.1469 - val_accuracy: 0.5020 - val_loss: 1.1312
# Epoch 24/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4988 - loss: 1.1481 - val_accuracy: 0.5001 - val_loss: 1.1251
# Epoch 25/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5012 - loss: 1.1421 - val_accuracy: 0.5011 - val_loss: 1.1231
# Epoch 26/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4968 - loss: 1.1403 - val_accuracy: 0.4997 - val_loss: 1.1295
# Epoch 27/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4973 - loss: 1.1391 - val_accuracy: 0.5003 - val_loss: 1.1260
# Epoch 28/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5007 - loss: 1.1358 - val_accuracy: 0.4982 - val_loss: 1.1201
# Epoch 29/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5007 - loss: 1.1312 - val_accuracy: 0.5026 - val_loss: 1.1173
# Epoch 30/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5049 - loss: 1.1299 - val_accuracy: 0.5051 - val_loss: 1.1163
# Epoch 31/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5014 - loss: 1.1298 - val_accuracy: 0.5005 - val_loss: 1.1193
# Epoch 32/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5019 - loss: 1.1248 - val_accuracy: 0.5045 - val_loss: 1.1118
# Epoch 33/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5060 - loss: 1.1244 - val_accuracy: 0.5063 - val_loss: 1.1103
# Epoch 34/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5056 - loss: 1.1168 - val_accuracy: 0.5059 - val_loss: 1.1073
# Epoch 35/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5071 - loss: 1.1167 - val_accuracy: 0.5115 - val_loss: 1.1059
# Epoch 36/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5029 - loss: 1.1160 - val_accuracy: 0.5084 - val_loss: 1.1046
# Epoch 37/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5100 - loss: 1.1150 - val_accuracy: 0.5065 - val_loss: 1.1020
# Epoch 38/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5099 - loss: 1.1096 - val_accuracy: 0.5096 - val_loss: 1.1034
# Epoch 39/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5068 - loss: 1.1097 - val_accuracy: 0.5065 - val_loss: 1.1031
# Epoch 40/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5124 - loss: 1.1048 - val_accuracy: 0.5094 - val_loss: 1.1030
# Epoch 41/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5080 - loss: 1.1114 - val_accuracy: 0.5072 - val_loss: 1.0968
# Epoch 42/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5113 - loss: 1.1035 - val_accuracy: 0.5101 - val_loss: 1.0978
# Epoch 43/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5119 - loss: 1.1022 - val_accuracy: 0.5101 - val_loss: 1.0936
# Epoch 44/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5138 - loss: 1.0995 - val_accuracy: 0.5094 - val_loss: 1.1002
# Epoch 45/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5150 - loss: 1.0962 - val_accuracy: 0.5101 - val_loss: 1.1001
# Epoch 46/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5176 - loss: 1.0907 - val_accuracy: 0.5080 - val_loss: 1.0957
# Epoch 47/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5160 - loss: 1.0952 - val_accuracy: 0.5088 - val_loss: 1.0932
# Epoch 48/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5153 - loss: 1.0974 - val_accuracy: 0.5138 - val_loss: 1.0900
# Epoch 49/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5157 - loss: 1.0893 - val_accuracy: 0.5086 - val_loss: 1.0917
# Epoch 50/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5173 - loss: 1.0830 - val_accuracy: 0.5113 - val_loss: 1.0897
# Epoch 51/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.5230 - loss: 1.0897 - val_accuracy: 0.5140 - val_loss: 1.0943
# Epoch 52/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5193 - loss: 1.0857 - val_accuracy: 0.5105 - val_loss: 1.0915
# Epoch 53/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5206 - loss: 1.0824 - val_accuracy: 0.5128 - val_loss: 1.0908
# Epoch 54/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5232 - loss: 1.0823 - val_accuracy: 0.5194 - val_loss: 1.0866
# Epoch 55/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5263 - loss: 1.0745 - val_accuracy: 0.5163 - val_loss: 1.0831
# Epoch 56/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5258 - loss: 1.0731 - val_accuracy: 0.5163 - val_loss: 1.0852
# Epoch 57/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5247 - loss: 1.0710 - val_accuracy: 0.5186 - val_loss: 1.0879
# Epoch 58/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5231 - loss: 1.0712 - val_accuracy: 0.5184 - val_loss: 1.0887
# Epoch 59/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5232 - loss: 1.0726 - val_accuracy: 0.5177 - val_loss: 1.0903
# Epoch 60/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5286 - loss: 1.0692 - val_accuracy: 0.5198 - val_loss: 1.0820
# Epoch 61/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.5287 - loss: 1.0653 - val_accuracy: 0.5150 - val_loss: 1.0902
# Epoch 62/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - accuracy: 0.5290 - loss: 1.0666 - val_accuracy: 0.5161 - val_loss: 1.0853
# Epoch 63/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - accuracy: 0.5278 - loss: 1.0653 - val_accuracy: 0.5209 - val_loss: 1.0844
# Epoch 64/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.5320 - loss: 1.0584 - val_accuracy: 0.5113 - val_loss: 1.0820
# Epoch 65/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 24s 29ms/step - accuracy: 0.5257 - loss: 1.0601 - val_accuracy: 0.5132 - val_loss: 1.0858
# Epoch 66/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - accuracy: 0.5315 - loss: 1.0575 - val_accuracy: 0.5159 - val_loss: 1.0846
# Epoch 67/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - accuracy: 0.5343 - loss: 1.0512 - val_accuracy: 0.5190 - val_loss: 1.0867
# Epoch 68/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.5310 - loss: 1.0537 - val_accuracy: 0.5115 - val_loss: 1.0895
# Epoch 69/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5271 - loss: 1.0551 - val_accuracy: 0.5150 - val_loss: 1.0881
# Epoch 70/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5350 - loss: 1.0469 - val_accuracy: 0.5092 - val_loss: 1.0959
#
# French model :
# Epoch 1/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5403 - loss: 1.0441 - val_accuracy: 0.5171 - val_loss: 1.0638
# Epoch 2/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5508 - loss: 1.0177 - val_accuracy: 0.5202 - val_loss: 1.0665
# Epoch 3/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5606 - loss: 0.9968 - val_accuracy: 0.5173 - val_loss: 1.0681
# Epoch 4/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5701 - loss: 0.9791 - val_accuracy: 0.5194 - val_loss: 1.0586
# Epoch 5/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5830 - loss: 0.9492 - val_accuracy: 0.5265 - val_loss: 1.0984
# Epoch 6/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5902 - loss: 0.9334 - val_accuracy: 0.5165 - val_loss: 1.0872
# Epoch 7/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5967 - loss: 0.9137 - val_accuracy: 0.5144 - val_loss: 1.0966
# Epoch 8/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.6091 - loss: 0.8904 - val_accuracy: 0.5063 - val_loss: 1.1498
# Epoch 9/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.6209 - loss: 0.8741 - val_accuracy: 0.5080 - val_loss: 1.1486
# Epoch 10/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.6303 - loss: 0.8541 - val_accuracy: 0.5080 - val_loss: 1.1446
# Epoch 11/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.6438 - loss: 0.8334 - val_accuracy: 0.4852 - val_loss: 1.2494
# Epoch 12/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.6502 - loss: 0.8140 - val_accuracy: 0.5094 - val_loss: 1.2029
# Epoch 13/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.6581 - loss: 0.8010 - val_accuracy: 0.4989 - val_loss: 1.1822
# Epoch 14/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.6689 - loss: 0.7796 - val_accuracy: 0.5067 - val_loss: 1.2165

# %%
loss_en, accuracy2_en = model_embeddings_en.evaluate(X_test_pad_en, y_test_en,verbose=0)
loss_fr, accuracy2_fr = model_embeddings_fr.evaluate(X_test_pad_fr, y_test_fr,verbose=0)

print("English model :")
print(f"Loss     : {loss_en:.4f}")
print(f"Accuracy : {accuracy2_en:.2}")
print("\nFrench model :")
print(f"Loss     : {loss_fr:.4f}")
print(f"Accuracy : {accuracy2_fr:.2}")
# Out:
# English model :
# Loss     : 1.0820
# Accuracy : 0.52
#
# French model :
# Loss     : 1.0586
# Accuracy : 0.52

# %% [markdown]
# <a id="model3"></a>
# ### 4.2 Model with pre-trained embeddings

# %%
def model3(embedding_matrix,embedding_dim = 100):
    vocab_size, embedding_dim = embedding_matrix.shape
   
    model = Sequential([
        Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix],
                  trainable=True),
        SpatialDropout1D(0.5),
        Conv1D(64, 5, activation='relu', padding='same'),
        GlobalMaxPooling1D(),
        BatchNormalization(), 
        
        Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.0001)),
        Dropout(0.5),
        Dense(5, activation='softmax')
    ])
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(loss='sparse_categorical_crossentropy', 
                      optimizer=optimizer, 
                      metrics=['accuracy'])
    return model

# %%
embedding_matrix = get_embedding_matrix(tokenizer_en, model_glove, vector_size)

model_embeddings = model3(embedding_matrix)
model_embeddings.build(input_shape=(None, max_length))
model_embeddings.summary()
# Out:
# Model: "sequential_32"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_32 (Embedding)        │ (None, 100, 100)       │     1,135,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout1d_3             │ (None, 100, 100)       │             0 │
# │ (SpatialDropout1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_36 (Conv1D)              │ (None, 100, 64)        │        32,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d_34         │ (None, 64)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_64 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_32 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_65 (Dense)                │ (None, 5)              │           165 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,169,965 (4.46 MB)
#  Trainable params: 1,169,837 (4.46 MB)
#  Non-trainable params: 128 (512.00 B)

# %%
log_dir = str(LOG_DIR / "fit" / f"{datetime.datetime.now().strftime("%Y%m%d-%H%M%S")}")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
early_stop = EarlyStopping(
    monitor='val_loss', 
    patience=5,          
    restore_best_weights=True 
)

history = model_embeddings.fit(
    X_train_pad_en, y_train_en,
    epochs=100,
    validation_data=(X_test_pad_en, y_test_en),
    callbacks=[tensorboard_callback,early_stop],
    batch_size=32
)
# Out:
# Epoch 1/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.2360 - loss: 2.0033 - val_accuracy: 0.2687 - val_loss: 1.5662
# Epoch 2/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.3247 - loss: 1.6433 - val_accuracy: 0.3314 - val_loss: 1.4717
# Epoch 3/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.3502 - loss: 1.5317 - val_accuracy: 0.3725 - val_loss: 1.4246
# Epoch 4/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.3770 - loss: 1.4638 - val_accuracy: 0.3970 - val_loss: 1.3949
# Epoch 5/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.3924 - loss: 1.4166 - val_accuracy: 0.4204 - val_loss: 1.3592
# Epoch 6/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4060 - loss: 1.3748 - val_accuracy: 0.4314 - val_loss: 1.3357
# Epoch 7/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4131 - loss: 1.3616 - val_accuracy: 0.4370 - val_loss: 1.3218
# Epoch 8/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4244 - loss: 1.3365 - val_accuracy: 0.4462 - val_loss: 1.2961
# Epoch 9/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4318 - loss: 1.3184 - val_accuracy: 0.4474 - val_loss: 1.2876
# Epoch 10/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4427 - loss: 1.2954 - val_accuracy: 0.4551 - val_loss: 1.2633
# Epoch 11/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4462 - loss: 1.2769 - val_accuracy: 0.4621 - val_loss: 1.2480
# Epoch 12/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.4482 - loss: 1.2700 - val_accuracy: 0.4621 - val_loss: 1.2348
# Epoch 13/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4505 - loss: 1.2602 - val_accuracy: 0.4659 - val_loss: 1.2240
# Epoch 14/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4602 - loss: 1.2409 - val_accuracy: 0.4698 - val_loss: 1.2165
# Epoch 15/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4629 - loss: 1.2306 - val_accuracy: 0.4742 - val_loss: 1.1966
# Epoch 16/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4659 - loss: 1.2269 - val_accuracy: 0.4762 - val_loss: 1.1977
# Epoch 17/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4658 - loss: 1.2174 - val_accuracy: 0.4798 - val_loss: 1.1844
# Epoch 18/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4717 - loss: 1.2040 - val_accuracy: 0.4812 - val_loss: 1.1853
# Epoch 19/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4723 - loss: 1.2011 - val_accuracy: 0.4783 - val_loss: 1.1801
# Epoch 20/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4727 - loss: 1.1997 - val_accuracy: 0.4802 - val_loss: 1.1725
# Epoch 21/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4757 - loss: 1.1903 - val_accuracy: 0.4821 - val_loss: 1.1629
# Epoch 22/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.4822 - loss: 1.1852 - val_accuracy: 0.4818 - val_loss: 1.1717
# Epoch 23/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4757 - loss: 1.1841 - val_accuracy: 0.4843 - val_loss: 1.1603
# Epoch 24/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4808 - loss: 1.1754 - val_accuracy: 0.4852 - val_loss: 1.1625
# Epoch 25/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.4868 - loss: 1.1700 - val_accuracy: 0.4835 - val_loss: 1.1509
# Epoch 26/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.4853 - loss: 1.1691 - val_accuracy: 0.4883 - val_loss: 1.1492
# Epoch 27/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 25s 31ms/step - accuracy: 0.4863 - loss: 1.1603 - val_accuracy: 0.4922 - val_loss: 1.1482
# Epoch 28/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - accuracy: 0.4864 - loss: 1.1635 - val_accuracy: 0.4910 - val_loss: 1.1478
# Epoch 29/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 20s 25ms/step - accuracy: 0.4905 - loss: 1.1487 - val_accuracy: 0.4910 - val_loss: 1.1483
# Epoch 30/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - accuracy: 0.4925 - loss: 1.1507 - val_accuracy: 0.4941 - val_loss: 1.1397
# Epoch 31/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4948 - loss: 1.1409 - val_accuracy: 0.4922 - val_loss: 1.1415
# Epoch 32/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4945 - loss: 1.1369 - val_accuracy: 0.4987 - val_loss: 1.1334
# Epoch 33/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4977 - loss: 1.1364 - val_accuracy: 0.4951 - val_loss: 1.1339
# Epoch 34/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4952 - loss: 1.1373 - val_accuracy: 0.4976 - val_loss: 1.1332
# Epoch 35/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4957 - loss: 1.1358 - val_accuracy: 0.4968 - val_loss: 1.1267
# Epoch 36/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4981 - loss: 1.1338 - val_accuracy: 0.4980 - val_loss: 1.1282
# Epoch 37/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4967 - loss: 1.1318 - val_accuracy: 0.4970 - val_loss: 1.1313
# Epoch 38/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4997 - loss: 1.1264 - val_accuracy: 0.4980 - val_loss: 1.1248
# Epoch 39/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4994 - loss: 1.1255 - val_accuracy: 0.4991 - val_loss: 1.1258
# Epoch 40/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.4986 - loss: 1.1193 - val_accuracy: 0.5009 - val_loss: 1.1234
# Epoch 41/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4994 - loss: 1.1286 - val_accuracy: 0.5009 - val_loss: 1.1228
# Epoch 42/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5008 - loss: 1.1202 - val_accuracy: 0.4999 - val_loss: 1.1185
# Epoch 43/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5037 - loss: 1.1126 - val_accuracy: 0.4972 - val_loss: 1.1187
# Epoch 44/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5086 - loss: 1.1121 - val_accuracy: 0.4984 - val_loss: 1.1210
# Epoch 45/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5032 - loss: 1.1112 - val_accuracy: 0.5013 - val_loss: 1.1153
# Epoch 46/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5057 - loss: 1.1071 - val_accuracy: 0.4978 - val_loss: 1.1143
# Epoch 47/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5053 - loss: 1.1091 - val_accuracy: 0.5007 - val_loss: 1.1099
# Epoch 48/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5068 - loss: 1.1085 - val_accuracy: 0.4997 - val_loss: 1.1171
# Epoch 49/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5094 - loss: 1.1013 - val_accuracy: 0.5022 - val_loss: 1.1058
# Epoch 50/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5044 - loss: 1.1031 - val_accuracy: 0.5026 - val_loss: 1.1094
# Epoch 51/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5090 - loss: 1.0969 - val_accuracy: 0.5001 - val_loss: 1.1090
# Epoch 52/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5089 - loss: 1.0960 - val_accuracy: 0.5022 - val_loss: 1.1049
# Epoch 53/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5073 - loss: 1.0958 - val_accuracy: 0.5030 - val_loss: 1.1072
# Epoch 54/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5127 - loss: 1.0911 - val_accuracy: 0.5047 - val_loss: 1.1065
# Epoch 55/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5109 - loss: 1.0884 - val_accuracy: 0.5036 - val_loss: 1.1052
# Epoch 56/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5134 - loss: 1.0856 - val_accuracy: 0.5022 - val_loss: 1.1095
# Epoch 57/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5133 - loss: 1.0827 - val_accuracy: 0.5038 - val_loss: 1.1027
# Epoch 58/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5170 - loss: 1.0791 - val_accuracy: 0.5049 - val_loss: 1.1026
# Epoch 59/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5168 - loss: 1.0794 - val_accuracy: 0.5032 - val_loss: 1.0996
# Epoch 60/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5193 - loss: 1.0758 - val_accuracy: 0.5047 - val_loss: 1.0976
# Epoch 61/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5157 - loss: 1.0802 - val_accuracy: 0.5036 - val_loss: 1.0972
# Epoch 62/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5189 - loss: 1.0693 - val_accuracy: 0.5051 - val_loss: 1.1036
# Epoch 63/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5202 - loss: 1.0720 - val_accuracy: 0.5063 - val_loss: 1.0978
# Epoch 64/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5229 - loss: 1.0674 - val_accuracy: 0.5067 - val_loss: 1.0953
# Epoch 65/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5198 - loss: 1.0708 - val_accuracy: 0.5040 - val_loss: 1.0985
# Epoch 66/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5252 - loss: 1.0657 - val_accuracy: 0.5067 - val_loss: 1.0936
# Epoch 67/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5240 - loss: 1.0630 - val_accuracy: 0.5036 - val_loss: 1.0976
# Epoch 68/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5252 - loss: 1.0673 - val_accuracy: 0.5057 - val_loss: 1.0963
# Epoch 69/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5235 - loss: 1.0656 - val_accuracy: 0.5061 - val_loss: 1.0955
# Epoch 70/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5237 - loss: 1.0595 - val_accuracy: 0.5084 - val_loss: 1.0945
# Epoch 71/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5232 - loss: 1.0609 - val_accuracy: 0.5082 - val_loss: 1.0928
# Epoch 72/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5301 - loss: 1.0537 - val_accuracy: 0.5065 - val_loss: 1.0974
# Epoch 73/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5270 - loss: 1.0590 - val_accuracy: 0.5094 - val_loss: 1.0955
# Epoch 74/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.5296 - loss: 1.0522 - val_accuracy: 0.5121 - val_loss: 1.0899
# Epoch 75/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5310 - loss: 1.0506 - val_accuracy: 0.5080 - val_loss: 1.0916
# Epoch 76/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5330 - loss: 1.0491 - val_accuracy: 0.5080 - val_loss: 1.0923
# Epoch 77/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5289 - loss: 1.0528 - val_accuracy: 0.5109 - val_loss: 1.0921
# Epoch 78/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5345 - loss: 1.0436 - val_accuracy: 0.5063 - val_loss: 1.0971
# Epoch 79/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5353 - loss: 1.0419 - val_accuracy: 0.5117 - val_loss: 1.0924

# %%
loss, accuracy2_bis = model_embeddings.evaluate(X_test_pad_en, y_test_en,verbose=0)

print(f"Loss     : {loss:.4f}")
print(f"Accuracy : {accuracy2_bis:.2}")
# Out:
# Loss     : 1.0899
# Accuracy : 0.51

# %% [markdown]
# <a id="model4"></a>
# ## 5. BERT model

# %% [markdown]
# <a id="model_bert"></a>
# ### 5.2 BERT

# %% [markdown]
# <a id="model5"></a>
# ## 7. LLM

# %% [markdown]
# <a id="comparaison"></a>
# ## 8. Comparaison
